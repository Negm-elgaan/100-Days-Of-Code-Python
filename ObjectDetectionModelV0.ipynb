# %% [markdown]
# <a href="https://colab.research.google.com/github/Negm-elgaan/100-Days-Of-Code-Python/blob/main/ObjectDetectionModelV0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch
# !pip install torchmetrics
import torch as T
import torch.nn as nn
from torchmetrics import Accuracy , Recall , Precision , MeanSquaredError
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 14.4 MB/s eta 0:00:00
# ...

# %%
x = T.zeros(2 , 0 , 32)
x
# Out:
# tensor([], size=(2, 0, 32))

# %%
LSTM = nn.LSTM(input_size = 4 , hidden_size = 32 , num_layers = 3 , batch_first = True)

# %%
class LongShortTermMemory(nn.Module):
  def __init__(self , input_size , hidden_size , num_layers , batch_first , fcinput , fcoutput):
    super().__init__()
    self.lstm = nn.LSTM(input_size = input_size , hidden_size = hidden_size , num_layers = num_layers , batch_first = batch_first)
    self.fc = nn.Linear(fcinput , fcoutput)
    self.num_layers = num_layers
    self.hidden_size = hidden_size
  def forward(self , x):
    h0 = torch.zeros(self.num_layers , x.size(0), self.hidden_size)
    c0 = torch.zeros(self.num_layers , x.size(0), self.hidden_size)
    out , _ = self.lstm(x , (h0 , c0))
    out = out[: , -1 , :]
    out = self.fc(out)
    return out
